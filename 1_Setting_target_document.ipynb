# %% [markdown]
# <a href="https://colab.research.google.com/github/kjh8331267/AI_policy_analysis/blob/main/1_Setting_target_document.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# Read data
file_path = "/content/drive/MyDrive/kdis_python/Overton_data.xlsx"
df = pd.read_excel(file_path)
data.head()
# Out:
#                                          Title  \
# 0     Relación Definitiva De Ayudas Concedidas
# 1     Relación Definitiva De Ayudas Concedidas
# 2                当翻訳は仮訳であり 、 正確には原文を参照してください 。
# 3                当翻訳は仮訳であり 、 正確には原文を参照してください 。
# 4  Ukatu Diren Laguntzen Behin Betiko Zerrenda
#
#                    Translated title   Published  \
# 0                               NaN  2020-10-07
# 1                               NaN  2022-03-07
# 2                               NaN  2024-04-16
# 3                               NaN  2024-01-18
# 4  Definitive List of Grants Denied  2020-10-07
#
#                                                  URL  \
# 0  https://www.euskadi.eus/contenidos/resolucion_...
# 1  https://www.euskadi.eus/contenidos/resolucion_...
# 2  https://www.soumu.go.jp/main_content/000943087...
# 3  https://www.soumu.go.jp/main_content/000923720...
# 4  https://www.euskadi.eus/contenidos/resolucion_...
#
# ...

# %%
# Replace 'Title' value with 'Translated title' when available
df['Title'] = df['Translated title'].combine_first(df['Title'])

# %% [markdown]
#  ## Filter by target countries

# %%
unique_countries = df['Source Country'].unique().tolist()
print(unique_countries)
# Out:
# ['Spain', 'Japan', 'USA', 'Brazil', 'UK', 'IGO', 'Canada', 'France', 'Netherlands', 'Australia', 'EU', 'Poland', 'Samoa', 'Sweden', 'Nigeria', 'Taiwan', 'United Arab Emirates', 'Germany', 'Singapore', 'Austria', 'Belgium', 'Switzerland', 'Tonga', 'Ecuador', 'New Zealand', 'Ireland', 'Finland', 'South Africa', 'Thailand', 'Luxembourg', 'Latvia', 'India', 'Egypt', 'Denmark', 'Uruguay', 'China', 'Italy', 'Slovenia', 'Honduras', 'Norway', 'Czech Republic', 'Peru', 'Trinidad and Tobago', 'Kenya', 'Guatemala', 'Philippines', 'Turkey', 'Colombia', 'Greece']

# %%
# Filter by target countries
target_countries = ['EU', 'UK', 'Spain', 'France', 'Germany', 'Netherlands', 'Sweden',
                    'Austria', 'Belgium', 'Switzerland', 'Poland', 'Italy', 'USA', 'IGO']
df = df[df['Source Country'].isin(target_countries)]

# %%
print("\nSource Country Distribution:")
print(df['Source Country'].value_counts())
# Out:
# Source Country Distribution:
# Source Country
# USA            284
# EU             179
# IGO            136
# UK             114
# France          58
# Spain           47
# Netherlands     23
# Belgium         18
# Sweden          11
# Germany         11
# Switzerland     11
# Italy           11
# Poland           3
# Austria          1
# Name: count, dtype: int64

# %% [markdown]
# ## Filter by publication date

# %%
df['Published'] = pd.to_datetime(df['Published'], errors='coerce')
df = df[df['Published'] >= '2023-01-01']

# %% [markdown]
# ## Save and check filtered data

# %%
filtered_file_path = '/content/drive/MyDrive/kdis_python/Filtered_Overton_data_with_titles.xlsx'
df.to_excel(filtered_file_path, index=False)

df.head()
# Out:
#                                                 Title  \
# 7                    Definitive List of Grants Denied
# 9                          Sellafield Ltd AI Strategy
# 10      AI Governance Alliance: Briefing Paper Series
# 18        Using AI in Industrial Operations Guidebook
# 20  COMMUNICATION FROM THE COMMISSION TO THE EUROP...
#
#                     Translated title  Published  \
# 7   Definitive List of Grants Denied 2023-03-13
# 9                                NaN 2023-03-23
# 10                               NaN 2024-01-18
# 18                               NaN 2023-10-09
# 20                               NaN 2024-01-25
#
#                                                   URL  \
# 7   https://www.euskadi.eus/contenidos/resolucion_...
# 9   https://www.gov.uk/government/publications/sel...
# 10  https://www.weforum.org/publications/ai-govern...
# 18  https://www.weforum.org/whitepapers/harnessing...
# 20  https://webapi2016.eesc.europa.eu/v1/documents...
#
# ...
